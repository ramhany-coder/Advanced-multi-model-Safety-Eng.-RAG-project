# %%
from gptcache.adapter.api import init_similar_cache
from gptcache.processor.pre import get_prompt
from langchain_community.cache import GPTCache
from langchain_core.globals import set_llm_cache
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from gptcache.adapter.api import init_similar_cache
#       2 from gptcache.processor.pre import get_prompt
#       3 from langchain_community.cache import GPTCache
#       4 from langchain_core.globals import set_llm_cache
#
# ModuleNotFoundError: No module named 'gptcache'
